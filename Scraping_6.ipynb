# %% [markdown]
# SCRAPING - ss 21
# ---------------
# > Chiara Piccolroaz
#
# > University of Konstanz
#
# > Department of Computer and Information Science; Department of political and administration science

# %% [markdown]
# IMPORTING PACKAGES
# --------------------------
#
# WEbseiten for Scraping Juris : https://www.juris.de/jportal/portal/ and https://rzblx10.uni-regensburg.de/dbinfo/detail.php?bib_id=ubko&colors=&ocolors=&lett=f&tid=0&titel_id=865
#
# WebSeite for Installing Selenium: : https://www.jcchouinard.com/learn-selenium-python-seo-automation/

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import selenium.webdriver.support.ui as ui
import requests, PyPDF2
from io import BytesIO

# %% [markdown]
# Go to Juris-website. Make sure to:
# 1. be locked in the Uni-WLAN or connected with the Uni-VPN
# 2. the packages have been download

# %%
driverC=webdriver.Chrome(executable_path=r"C:\chromedriver_win32\chromedriver.exe") 
driverC.get('https://www.juris.de/jportal/?action=JLoginUser&username=HEBISUKN.autologin')
driverC.get('https://www.juris.de/r3/search')
driverC.maximize_window()

# %% [markdown]
# Select the relevant filers and buttons. Make sure to:
# 1. run the sleep functions, otherwise the other functions will override.
# 2. the chrome window is maximized
# 3. the previous function has run

# %%
button = driverC.find_element_by_id("categories_hits_Rechtsprechung")
button.click()
time.sleep(2) 
button = driverC.find_element_by_id("filter_Sachgebiete")
button.click()
time.sleep(2) 
button = driverC.find_element_by_id("filter_Asylis___MILo")
button.click()
time.sleep(2) 
button = driverC.find_element_by_id("filter_apply")
button.click()
time.sleep(2) 
button = driverC.find_element_by_id("linkWorkId80896")
button.click()
time.sleep(2)

# %% [markdown]
# 1. Collect the links:
#
# general Procedure: Collect the link of the pdfs for each of the 19151 elements. In order to do that use the following function, which enters each of the 19151 element files, get all PDFs and save them in a list.

# %%
# 0. Initialisation

# the list the PDF-files are gonna be saved in
listPDFs = [] 
# i refers to the number of ducuments pro page and gives the function the id of the document we are looking for. Put i = j = 0
i = 0 
# j refers to the number of documents in total. Put i = j = 0
j = 0
# p refers to the number of the page 
p = 1

# 0. repeat the function for the number of the documents: 
while j < 20491:
    # get the name
    # create the string, which indicates the element_id on the website, which we want to enter the element file with 
    str1 ='resultlistentry_LI' 
    str2 = "{}".format(i)
    str = str1 + str2
    print(str) 
    
# 1. enter the element´s file
    Urteil = driverC.find_element_by_id(str) 
    Urteil.click()
    time.sleep(2) 
    
# 2. get the PDF-link(s) from the respective element´s file
    # get the links and put in the list linkList
    links=driverC.find_elements_by_tag_name("a")
    linkList = [link.get_attribute('href') for link in links]
    time.sleep(2)
    # clean the list linkList, in order to have only strings
    clean_linkList = [i for i in linkList if i is not None]
    # count how many PDFs are, which we are interested in:and according to that:  
    count = 0
    sub = '/jportal/docs/anlage/as/bilder/'
    for link in clean_linkList:
        if sub in link:
            count = count +1
    # if these are more than just one PDF: select the links and add it to the list linkPDF as a list
    linkPDF = []
    if count > 1:
        print('multiple PDFs')
        for link in clean_linkList:
            if sub in link:
                linkPDF.append(link)         
    # if there is only one PDF: select the link and add to the list linkPDF;       
    if count == 1:
        print("got the PDFs, go one back")
        for link in clean_linkList:
            if sub in link:
                linkPDF = link
    # if there are no PDFs: do nothing  
    if count < 1:
        print('no PDF') 
        
# 4. add the PDF(s) in the ListPDFs
    listPDFs.append(linkPDF)
    #print(listPDFs)
    time.sleep(2)
    
# 5. go back to the main page and go on with the other elements
    backtoList = driverC.find_element_by_class_name("tlrahmen")
    backtoList.click()
    time.sleep(4) 
    
# 6. increase i to check for the elements pro page; increase j to check for the 19151 elements
    i = i+1
    j = j+1 
    
# 6. if te last element change the page 
    if i == 25: 
        print("i is equal 25 - we got the 25th element of the page -, so change page")  
        p = p+1
        print("NEXT page" , p)
        driverC.execute_script("window.scrollTo(0, 0);")
        button = driverC.find_element_by_class_name("svg-icon-chevron_right")
        button.click()
        time.sleep(4)  
        i= 0
# Out:
# resultlistentry_LI0
# no PDF
# resultlistentry_LI1
# no PDF
# resultlistentry_LI2
# no PDF
# resultlistentry_LI3
# got the PDFs, go one back
# resultlistentry_LI4
# got the PDFs, go one back
# resultlistentry_LI5
# got the PDFs, go one back
# resultlistentry_LI6
# got the PDFs, go one back
# resultlistentry_LI7
# no PDF
# resultlistentry_LI8
# got the PDFs, go one back
# resultlistentry_LI9
# got the PDFs, go one back
# resultlistentry_LI10
# no PDF
# resultlistentry_LI11
# no PDF
# resultlistentry_LI12
# got the PDFs, go one back
# resultlistentry_LI13
# no PDF
# resultlistentry_LI14
# got the PDFs, go one back
# resultlistentry_LI15
# got the PDFs, go one back
# resultlistentry_LI16
# got the PDFs, go one back
# resultlistentry_LI17
# no PDF
# resultlistentry_LI18
# got the PDFs, go one back
# resultlistentry_LI19
# no PDF
# resultlistentry_LI20
# got the PDFs, go one back
# resultlistentry_LI21
# got the PDFs, go one back
# resultlistentry_LI22
# got the PDFs, go one back
# resultlistentry_LI23
# got the PDFs, go one back
# resultlistentry_LI24
# got the PDFs, go one back
# i is equal 25 - we got the 25th element of the page -, so change page
# NEXT page 2
# resultlistentry_LI0
# got the PDFs, go one back
# resultlistentry_LI1
# got the PDFs, go one back
# resultlistentry_LI2
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-6-804229effc64> in <module>
#      21 # 1. enter the element´s file
#      22     Urteil = driverC.find_element_by_id(str)
# ---> 23     Urteil.click()
#      24     time.sleep(2)
#      25
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <li id="resultlistentry_LI2" class="result-list__entry">...</li> is not clickable at point (845, 53). Other element would receive the click: <nav id="ID_STICKY_SITE_HEADER_HEADER_MAIN_NAVI" class="sticky-site-header__header-main-navi">...</nav>
#   (Session info: chrome=91.0.4472.124)

# %%
with open('listPDFs.txt', 'w') as f:
    for item in listPDFs:
        f.write("%s\r\n" % item)

# %%
listPDFs
# Out:
# [[],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18455390.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17130144.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16634543.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16387029.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15207340.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19439387.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16930276.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17875187.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15256689.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15256689.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/13911157.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17331133.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17247329.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/14713504.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15802375.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17113139.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17486062.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17255995.pdf',
#  ['https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/12711966.pdf',
#   'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/
pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/nare200600164_mm00300945.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15270389.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/nare200500448_mm00287903.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18933352.pdf',
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18626446.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18589012.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15442806.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18434482.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17377531.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19128918.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17976387.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17523983.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17848843.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16930292.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18891016.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15372980.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11870459.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18739267.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19309161.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16763180.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11615340.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11822509.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11002976.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10841484.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10746904.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17523778.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10092184.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/13595327.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17104859.pdf',
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18411282.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/nare200600243_mm00303638.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17306041.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19265698.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/13440522.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17151611.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17020745.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16102117.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16662964.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18493725.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18969748.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/nare200400899_mm00269355.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18235904.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15598292.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18503115.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17848378.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18131428.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/14620924.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/12027829.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15615809.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16130545.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15458259.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/14655505.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11487730.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18970271.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18736725.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18685041.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11853587.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11025905.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17047509.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17693161.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19090337.pdf',
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18160705.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10719649.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10802389.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/14063289.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10588179.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/nare200600141_mm00300117.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16687677.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17841790.pdf',
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17848830.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18235472.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16136401.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18730912.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18081320.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16954244.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16945070.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16958628.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/14128415.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15877281.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/12202980.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/nare200200031_mm00002751.pdf',
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10202335.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18400484.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16391204.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11901081.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11006787.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11314529.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11460902.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11822504.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10999403.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11706087.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10785717.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11167989.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11163158.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18393504.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17965369.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19588902.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18881145.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/9308732.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19292532.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/nare200600153_mm00300187.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/12107381.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18411306.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16090539.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19266264.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17046704.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15187238.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15373094.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15751571.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17521675.pdf',
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19226122.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11892161.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18970498.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18088264.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19267450.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17652803.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/13788214.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18075583.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18393471.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10796313.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18684306.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19207047.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/13701955.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/14620930.pdf',
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/13439219.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/12390224.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/13627148.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15144371.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19331389.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16687897.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19265696.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19226611.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/19300159.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18943322.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/16510562.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11660155.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18784328.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15549485.pdf',
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11543381.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11258984.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/17998149.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/15353090.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/13863348.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/18932927.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11866622.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11870481.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11873380.pdf',
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/14183464.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/7716687.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11866603.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11615345.pdf',
#  [],
#  [],
#  [],
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11508427.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11477992.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11532293.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11853576.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11856823.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11133734.pdf',
#  [],
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/10957516.pdf',
#  'https://www.juris.de/jportal/docs/anlage/as/bilder/bafl/11818916.pdf',
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# To get the PDF content

# %%
TextList = []

for link in listPDFs:
    Pages = []
    response = requests.get(link)
    my_raw_data = response.content
    
    with BytesIO(my_raw_data) as data:
        read_pdf = PyPDF2.PdfFileReader(data)
        
        for page in range(read_pdf.getNumPages()):
            p =read_pdf.getPage(page).extractText()
            p = p.replace("\n", "")
            Pages.append(p)
        JointPages = "".join(Pages)
        TextList.append(JointPages)

# %%
TextList
# Out:
# '  PDF Test File  Congratulations, your computer is equipped with a PDF (Portable Document Format) reader!  You should be able to view any of the PDF documents and forms available on our site.  PDF forms are indicated by these icons: \n  or  \n.    Yukon Department of Education Box 2703 Whitehorse,Yukon Canada Y1A 2C6  Please visit our website at:  \nhttp://www.education.gov.yk.ca/\n   '

# %%
with open('test.txt', 'w') as f:
    for item in TextList:
        f.write("%s\r\n" % item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-52160eb54a8d> in <module>
#       1 with open('test.txt', 'w') as f:
# ----> 2     for item in TextList:
#       3         f.write("%s\r\n" % item)
#
# NameError: name 'TextList' is not defined
